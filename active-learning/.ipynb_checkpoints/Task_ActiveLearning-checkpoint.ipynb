# %% [markdown]
# ### Machine Learning II
# ### Módulo Active Learning
# #### Trabajo realizado por:
# Guillermo Climent <br>
# Rubén Gímenez<br>
# Mayra Russo

# %% [markdown]
# ### Objetivo
# El objetivo de este trabajo es ensayar los métodos de active learning vistos en clase sobre el dataset Semeion Handwritting Digit.
# ### Active Learning
# Los algoritmos de Active Learning permiten proactivamente seleccionar un sub-set de ejemplos que deberan ser etiquetados de un conjunto de instancias sin etiquitar. AL se basa en etiquetar datos durante la fase de entranamiento de una manera incremental y dináminca, de manera que permita al algoritmo identificar que etiquetas van a ser las más informativas para de ese modo aprenderlas más rápido.
# ### Dataset
# El dataset consiste en 1593 registros y 256 variables.
# Cada registro representa un dígito manuscrito posteriormente digitalizado en tamaño  16 x 16 (256 dimensiones). <br>
# Fuente: [UCI](https://archive.ics.uci.edu/ml/datasets/Semeion+Handwritten+Digit)

# %% [markdown]
# ### Trabajo a realizar
# La tarea consiste de dos partes, por un lado vamos a implementar un programa para clasificar nuestras muestras combinando las diferentes estrategias de active learning y diversidad estudiadas, empleando un SVM como clasificador base. <br>
# Una vez implementado nuestro programa, procederemos a analizar los resultados que hemos obtenido tras aplicar las distintas combinaciones, generando gráficas comparativas de nuestros resultados.
# <br>

# %% [markdown]
# #### <u>Estrategias de Active Learning</u>
# <b>MS (margin sampling):<br></b>
# Basado en las propiedades geométricas del SVM, esta estrategia minimiza la distancia hacía el hiperplano más cercano<br>
# <b>MCLU (multi-class label uncertainty):<br></b>
# Considera la confianza de las dos clases más probables<br>
# <b>SSC (significance space construction):<br></b>
# Esta heurística usa las muestras de entrenamiento para definir una segunda función de clasificación, la cual es empleada sobre el conjunto de candidatos para predecir que muestras son las más probables para convertirse en vectores soporte.<br>
# Como paso adicional durante la implementación de esta estrategia, tras obtener los candidatos a vectores soporte con el clasificador SVM, vamos a iniciar una matriz (0,1) con la misma forma de la matriz de etiquetas, donde los ‘0’ son puntos no candidatos a vectores soporte, y los ‘1’ son candidatos. Posteriormente, entrenaremos un clasificador binario, decision tree, para predecir qué puntos serán vectores soporte del conjunto de datos no etiquetados.<br>
# <b>nEQB (normalized entropy query bagging):<br> </b>
# Modelo basado en la consideración de un comité de métodos de aprendizaje. Esta estrategia propone bagging para crear el comité.
#
# #### <u>Algoritmos 'diversity'</u>
# Estos algoritmos se emplean con el fin de que una vez se han seleccionado las muestras dentro de los conjuntos de candidatos, nos podamos asegurar de que estos son lo suficientemente diversos antes de añadirlos al conjunto de entrenamiento. <br>
# <br>
# <b>MAO: most ambiguous and orthogonal <br></b>
# Esta estrategia se basa en escoger muestras que minimicen los valores más altos dentro de la lista de candidatos. <br>
# <b>MCLU-ABD: multiclass level uncertainty-angle-based diversity <br></b>
# Esta estrategia combina el criterio MAO, con MCLU, llevándose a cabo mediante la selección de un subset de nuestro conjunto de candidatos que maximice el criterio de MCLU. <br>
# <b>Diversity by clustering <br></b>
# Esta última estrategia se encarga de asegurar la diversidad mediante clustering en el espacio de características.
# <br>

# %% [markdown]
# #### Importación de Librerias y Datos

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.utils import resample
from our_al_base import ao, show_results
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeClassifier
# Import RBF kernel
from sklearn.metrics.pairwise import rbf_kernel

import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

import time

SEED = 666
np.random.seed(SEED)

# Data Import
train_labeled_path = "data/semeion_labeled.csv"
train_unlabaled_path = "data/semeion_unlabeled.csv"
test_path = "data/semeion_test.csv"

train_labeled = pd.read_csv(train_labeled_path, header = None, delimiter = ",")
train_unlabeled = pd.read_csv(train_unlabaled_path, header = None, delimiter = ",")

test = pd.read_csv(test_path, header = None, delimiter = ",")

## TRAIN ##
# split into data and labels
labeled_data = train_labeled.iloc[:, 1:] .to_numpy()
labels = train_labeled.iloc[:,0].to_numpy()

unlabeled_data = train_unlabeled.iloc[:, 1:].to_numpy()
labels_u = train_unlabeled.iloc[:, 0].to_numpy() # do NOT use

## TEST ##
test_data  = test.iloc[:,1:].to_numpy()
test_labels = test.iloc[:,0].to_numpy()

# %% [markdown]
# ##### Implementación Algoritmos 'diversity'

# %%
## Diversity Methods ##
def MAO_Diversity(idx):
    # Lets limit the pool of possible samples as:
    idx = idx[0:query_points * 10]
    # Measure distances using the kernel function
    K = rbf_kernel(active.xunlab, gamma=active.gamma)
    Sidx = np.zeros(query_points, dtype=type(idx[0]))
    for j in np.arange(query_points):
        # Add the first point (and remove it from pool)
        Sidx[j] = idx[0]
        idx = idx[1:]
        # Compute distances (kernel matrix)
        # Distances between selected samples (Sidx) and the rest (idx)
        Kdist = K[Sidx[0:j+1],:][:,idx]
        # Obtain the minimum distance for each column
        Kdist = Kdist.min(axis=0)
        # Re-order by distance
        idx = idx[Kdist.argsort(axis=0)]
    # Move selected samples from unlabeled set to labeled set
    return active.updateLabels(Sidx)

def MAO_lambda_Diversity(idx, yp, ssc_method = "none", lam = 0.6):
    # MAO lambda: trade-off between uncertainty and diversity
    K = rbf_kernel(active.xunlab, gamma = active.gamma) #provisional kernel
    Sidx = np.zeros(query_points, dtype=type(idx[0]))
    for j in np.arange(query_points):
        # Add the first point, and remove it from pool
        Sidx[j] = idx[0]
        idx = idx[1:]
        # Compute distances (kernel matrix)
        # Distances between selected samples (Sidx) and the rest (idx)
        Kdist = np.abs(K[Sidx[0:j+1],:][:,idx])
        # Obtain the minimum distance for each column
        Kdist = Kdist.min(axis=0)
        # Trade-off between AL algorithm and Diversity
        if ssc_method == "ssc":
            heuristic = yp[idx, -1] * lam + Kdist * (1 - lam)
        elif ssc_method == "none":
            heuristic = yp[idx] * lam + Kdist * (1 - lam)
        idx = idx[heuristic.argsort()]  # axis=0
    # Move selected samples from unlabeled set to labeled set
    return active.updateLabels(Sidx)

def Cluster_Diversity(idx):
    # Init kmeans
    kmeans = KMeans(n_clusters=min(query_points, len(active.xunlab[idx])), random_state = SEED)
    # 1. Cluster the unlabeled set
    clusterIDs = kmeans.fit_predict(active.xunlab[idx])
    # 2. Select one sample per cluster.
    Sidx = np.zeros((query_points,), dtype=int)
    for j in np.arange(query_points):
        Sidx[j] = idx[clusterIDs == j][0]
    # Move selected samples from unlabeled set to labeled set
    return active.updateLabels(Sidx)

# %% [markdown]
# ##### Implementación Algoritmos AL

# %%
## Active Learning Algorithms ##
def Random_Sampling(xlab, ylab, xunlab):
    # 1. Fit random model
    random.classifier.fit(xlab, ylab)
    # 2. Choose some random samples from xunlab, yunlab
    idx = np.random.permutation(xunlab.shape[0])
    # 3. Call updateLabels to move them from pool to train
    return random.updateLabels(idx[0:query_points])

def MarginSampling(xlab, ylab, xunlab, div_method):
    active.classifier.fit(xlab, ylab)
    # Use heuristic to choose samples from pool
    dist = np.abs(active.classifier.decision_function(active.xunlab))
    dist = np.sort(dist, axis = 1)
    dist = dist[:, 0] #why
    idx = np.argsort(dist)
    # determine diversity method
    if div_method == "none":
        return  active.updateLabels(idx[0:query_points])
    elif div_method == "mao_div":
        return MAO_Diversity(idx = idx)
    elif div_method == "mao_lambda_div":
        return MAO_lambda_Diversity(idx = idx, yp = dist)
    elif div_method == "clustering_div":
        return Cluster_Diversity(idx = idx)

def MCLU(xlab, ylab, xunlab, div_method):
    active.classifier.fit(active.xlab, active.ylab)
    # Use heuristic to choose samples from pool
    dist = np.abs(active.classifier.decision_function(xunlab))
    dist = np.sort(dist, axis=1)
    dist = dist[:,-1] - dist[:,-2]
    idx = np.argsort(dist)
    # determine diversity method
    if div_method == "none":
        return active.updateLabels(idx[0:query_points])
    elif div_method == "mao_div":
        return MAO_Diversity(idx = idx)
    elif div_method == "mao_lambda_div":
        return MAO_lambda_Diversity(idx = idx, yp = dist)
    elif div_method == "clustering_div":
        return Cluster_Diversity(idx = idx)

def SSC(xlab, ylab, xunlab, div_method):
    model = DecisionTreeClassifier(random_state = SEED)
    active.classifier.fit(xlab, ylab)
    xtr = xlab
    ytr = ylab
    ytr = np.zeros(ytr.shape)
    ytr[active.classifier.support_] = 1
    if len(np.unique(ytr)) == 1:
        idx = np.random.permutation(xunlab.shape[0])
    else:
        model.fit(xtr, ytr)
        possible_SVs = model.predict(xunlab)
        idx = np.arange(xunlab.shape[0])[possible_SVs == 1]
        idx = np.random.permutation(idx)
    # determine diversity method
    if div_method == "none":
        return active.updateLabels(idx[0:query_points])
    elif div_method == "mao_div":
        return MAO_Diversity(idx = idx)
    elif div_method == "mao_lambda_div":
        dist = np.abs(active.classifier.decision_function(xunlab))
        return MAO_lambda_Diversity(idx = idx, yp = dist, ssc_method = "ssc")
    elif div_method == "clustering_div":
        return Cluster_Diversity(idx = idx)

def nEQB(xlab, ylab, xunlab, div_method,n_models = 4):
    # Number of models
    n_models = n_models
    # Base classifier for committee
    model = SVC(C=active.C, gamma=active.gamma)
    active.classifier.fit(xlab, ylab)
    # Use heuristic to choose samples from pool
    n_unlab = xunlab
    n_unlab = n_unlab.shape[0]
    predMatrix = np.zeros((n_unlab, n_models))
    for j in range(n_models):
        # Replica bootstrap
        while True:
            xbag, ybag = resample(xlab, ylab, replace=True)
            # Ensure that we have all classes in the bootstrap replica
            if len(np.unique(ybag)) >= n_classes:
                break
        model.fit(xbag, ybag)
        predMatrix[:, k] = model.predict(xunlab)
    # Count number of votes per class
    ct = np.zeros((xunlab.shape[0], n_classes))
    for i, w in enumerate(classes):
        ct[:, i] = np.sum(predMatrix == w, axis=1)
    ct /= n_models
    Hbag = ct.copy()
    # Set to 1 where Hbag == 0 to avoid -Inf and NaNs (problem is that 0 * -Inf = NaN)
    Hbag[Hbag == 0] = 1
    Hbag = -np.sum(ct * np.log(Hbag), axis=1) #este pal lambda
    logNi = np.log(np.sum(ct > 0, axis=1))
    # Avoid division by zero
    logNi[logNi == 0] = 1
    nEQB = Hbag / logNi
    # Select randomly one element among the ones with maximum entropy
    idx = np.where(nEQB == np.max(nEQB))[0]
    np.random.shuffle(idx)
    # determine diversity method
    if div_method == "none":
        return active.updateLabels(idx[0:query_points])
    elif div_method == "mao_div":
        return MAO_Diversity(idx = idx)
    elif div_method == "mao_lambda_div":
        return MAO_lambda_Diversity(idx = idx, yp = Hbag)
    elif div_method == "clustering_div":
        return Cluster_Diversity(idx = idx)

# %% [markdown]
# #### Ejercicio 1
# Implementación de un programa para clasificar nuestras muestras combinando las diferentes estrategias de active learning y diversidad, empleando un SVM como clasificador base.

# %%
# AL Variables
num_queries = 40
query_points = 10

classes = np.unique(labels)
n_classes = len(classes)

# Setup random and active objects
random = ao()
xtest, ytest = random.setup(labeled_data, labels, unlabeled_data, labels_u, test_data, test_labels)
white_class = random.copy()
# active = white_class.copy()

# Packing AL Algorithms % Diversity Criterions
algorithms = [MarginSampling, MCLU, SSC,  nEQB]
div_methods = ["none", "mao_div", "mao_lambda_div", "clustering_div"]


# Saving average accuracies & 2*sd
average_accuracies = pd.DataFrame()
alg_names = []
alg_div_names = []
avg_acc = []
std2 = []

for d in range(len(div_methods)):
    for k in range(len(algorithms)):
        # Update class instances for each AL algorithm iteration
        active = white_class.copy()
        random = white_class.copy()
        # Save Accuracy for each method
        accr_list = []
        acca_list = []
        for i in np.arange(0, num_queries):
            # print(i)
            # Random Method
            Random_Sampling(random.xlab, random.ylab, random.xunlab)
            accr = random.score(xtest, ytest)
            accr_list.append(accr)

            # AL
            algorithm = algorithms[k]
            algorithm(active.xlab, active.ylab, active.xunlab, div_method = div_methods[d])
            acca = active.score(xtest, ytest)
            acca_list.append(acca)
        # Packing accuracies into a DataFrame
        accuracies = pd.DataFrame()
        accuracies[algorithms[k].__name__] = acca_list
        accuracies["Random"] = accr_list
        # Printing Accuracy Results for itetations 10, 25, 50 & 70
        print("Algorithm:", algorithms[k].__name__," | ","Diversity Criterion:", div_methods[d])
        print("--------------------------------------------------------------")
        for quer in [4, 9, 14, 19]:
            print(quer+1, "queries:")
            print("Random ACC: %6.3f, Active ACC: %6.3f" % (accuracies.iloc[quer,1], accuracies.iloc[quer,0]))
        # Saving positions where non-random algorithm overcomes the random one
        aux = accuracies[accuracies[algorithms[k].__name__] > accuracies["Random"]]
        print("\nTimes", algorithms[k].__name__, "overcomes Random Sampling: ", aux.shape[0])
        # Printing in which n of queries AL algorithm performs better
        if aux.shape[0] == 0:
            aux1 = accuracies.sort_values([algorithms[k].__name__], ascending=False)
            print("Highest performance of", algorithms[k].__name__, "with", aux1.index[0]+1, "queries")
            aux1 = aux1.reset_index(drop=True)
            print("Random ACC: %6.3f, Active ACC: %6.3f" % (aux1.iloc[0,1], aux1.iloc[0,0]))
        else:
            aux1 = aux.sort_values([algorithms[k].__name__], ascending=False)
            print("Highest performance of", algorithms[k].__name__, "with", aux1.index[0]+1, "queries")
            aux1 = aux1.reset_index(drop=True)
            print("Random ACC: %6.3f, Active ACC: %6.3f" % (aux1.iloc[0,1], aux1.iloc[0,0]))
        # Plotting Accuracy Graphs
        plt.figure(figsize=(9, 5))
        plt.suptitle("Accuracy Scores, Random Sampling VS " + algorithms[k].__name__, fontsize=16)
        plt.title("Diversity Method: " + div_methods[d], fontsize=12)
        plt.xlabel("Number of Queries")
        plt.ylabel("Accuracy")
        ax = sns.lineplot(data=accuracies, palette="viridis")
        ax.legend(loc="lower right")
        plt.show()
        print("\n")
# Out:
# Algorithm: MarginSampling  |  Diversity Criterion: none
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.610, Active ACC:  0.520
# 10 queries:
# Random ACC:  0.826, Active ACC:  0.735
# 15 queries:
# Random ACC:  0.840, Active ACC:  0.762
# 20 queries:
# Random ACC:  0.856, Active ACC:  0.804
#
# Times MarginSampling overcomes Random Sampling:  0
# Highest performance of MarginSampling with 39 queries
# Random ACC:  0.925, Active ACC:  0.864
# Algorithm: MCLU  |  Diversity Criterion: none
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.671, Active ACC:  0.661
# 10 queries:
# Random ACC:  0.785, Active ACC:  0.854
# 15 queries:
# Random ACC:  0.873, Active ACC:  0.884
# 20 queries:
# Random ACC:  0.889, Active ACC:  0.909
#
# Times MCLU overcomes Random Sampling:  35
# Highest performance of MCLU with 40 queries
# Random ACC:  0.906, Active ACC:  0.937
# Algorithm: SSC  |  Diversity Criterion: none
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.655, Active ACC:  0.716
# 10 queries:
# Random ACC:  0.790, Active ACC:  0.818
# 15 queries:
# Random ACC:  0.821, Active ACC:  0.871
# 20 queries:
# Random ACC:  0.861, Active ACC:  0.893
#
# Times SSC overcomes Random Sampling:  34
# Highest performance of SSC with 36 queries
# Random ACC:  0.909, Active ACC:  0.922
# Algorithm: nEQB  |  Diversity Criterion: none
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.707, Active ACC:  0.708
# 10 queries:
# Random ACC:  0.834, Active ACC:  0.843
# 15 queries:
# Random ACC:  0.873, Active ACC:  0.876
# 20 queries:
# Random ACC:  0.889, Active ACC:  0.873
#
# Times nEQB overcomes Random Sampling:  12
# Highest performance of nEQB with 36 queries
# Random ACC:  0.906, Active ACC:  0.909
# Algorithm: MarginSampling  |  Diversity Criterion: mao_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.682, Active ACC:  0.552
# 10 queries:
# Random ACC:  0.770, Active ACC:  0.715
# 15 queries:
# Random ACC:  0.824, Active ACC:  0.777
# 20 queries:
# Random ACC:  0.867, Active ACC:  0.815
#
# Times MarginSampling overcomes Random Sampling:  0
# Highest performance of MarginSampling with 40 queries
# Random ACC:  0.909, Active ACC:  0.904
# Algorithm: MCLU  |  Diversity Criterion: mao_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.693, Active ACC:  0.682
# 10 queries:
# Random ACC:  0.839, Active ACC:  0.795
# 15 queries:
# Random ACC:  0.854, Active ACC:  0.886
# 20 queries:
# Random ACC:  0.882, Active ACC:  0.933
#
# Times MCLU overcomes Random Sampling:  32
# Highest performance of MCLU with 29 queries
# Random ACC:  0.903, Active ACC:  0.947
# Algorithm: SSC  |  Diversity Criterion: mao_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.649, Active ACC:  0.657
# 10 queries:
# Random ACC:  0.798, Active ACC:  0.776
# 15 queries:
# Random ACC:  0.865, Active ACC:  0.846
# 20 queries:
# Random ACC:  0.889, Active ACC:  0.848
#
# Times SSC overcomes Random Sampling:  15
# Highest performance of SSC with 40 queries
# Random ACC:  0.915, Active ACC:  0.923
# Algorithm: nEQB  |  Diversity Criterion: mao_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.603, Active ACC:  0.605
# 10 queries:
# Random ACC:  0.812, Active ACC:  0.785
# 15 queries:
# Random ACC:  0.868, Active ACC:  0.851
# 20 queries:
# Random ACC:  0.903, Active ACC:  0.879
#
# Times nEQB overcomes Random Sampling:  15
# Highest performance of nEQB with 38 queries
# Random ACC:  0.920, Active ACC:  0.939
# Algorithm: MarginSampling  |  Diversity Criterion: mao_lambda_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.660, Active ACC:  0.660
# 10 queries:
# Random ACC:  0.818, Active ACC:  0.804
# 15 queries:
# Random ACC:  0.848, Active ACC:  0.829
# 20 queries:
# Random ACC:  0.881, Active ACC:  0.829
#
# Times MarginSampling overcomes Random Sampling:  1
# Highest performance of MarginSampling with 13 queries
# Random ACC:  0.829, Active ACC:  0.837
# Algorithm: MCLU  |  Diversity Criterion: mao_lambda_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.613, Active ACC:  0.770
# 10 queries:
# Random ACC:  0.784, Active ACC:  0.842
# 15 queries:
# Random ACC:  0.859, Active ACC:  0.889
# 20 queries:
# Random ACC:  0.893, Active ACC:  0.911
#
# Times MCLU overcomes Random Sampling:  39
# Highest performance of MCLU with 39 queries
# Random ACC:  0.923, Active ACC:  0.939
# Algorithm: SSC  |  Diversity Criterion: mao_lambda_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.658, Active ACC:  0.704
# 10 queries:
# Random ACC:  0.824, Active ACC:  0.799
# 15 queries:
# Random ACC:  0.890, Active ACC:  0.810
# 20 queries:
# Random ACC:  0.890, Active ACC:  0.832
#
# Times SSC overcomes Random Sampling:  4
# Highest performance of SSC with 5 queries
# Random ACC:  0.658, Active ACC:  0.704
# Algorithm: nEQB  |  Diversity Criterion: mao_lambda_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.655, Active ACC:  0.520
# 10 queries:
# Random ACC:  0.755, Active ACC:  0.661
# 15 queries:
# Random ACC:  0.799, Active ACC:  0.718
# 20 queries:
# Random ACC:  0.839, Active ACC:  0.843
#
# Times nEQB overcomes Random Sampling:  22
# Highest performance of nEQB with 40 queries
# Random ACC:  0.923, Active ACC:  0.944
# Algorithm: MarginSampling  |  Diversity Criterion: clustering_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.613, Active ACC:  0.614
# 10 queries:
# Random ACC:  0.823, Active ACC:  0.768
# 15 queries:
# Random ACC:  0.868, Active ACC:  0.821
# 20 queries:
# Random ACC:  0.889, Active ACC:  0.848
#
# Times MarginSampling overcomes Random Sampling:  3
# Highest performance of MarginSampling with 5 queries
# Random ACC:  0.613, Active ACC:  0.614
# Algorithm: MCLU  |  Diversity Criterion: clustering_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.633, Active ACC:  0.743
# 10 queries:
# Random ACC:  0.809, Active ACC:  0.850
# 15 queries:
# Random ACC:  0.850, Active ACC:  0.873
# 20 queries:
# Random ACC:  0.871, Active ACC:  0.895
#
# Times MCLU overcomes Random Sampling:  39
# Highest performance of MCLU with 31 queries
# Random ACC:  0.912, Active ACC:  0.936
# Algorithm: SSC  |  Diversity Criterion: clustering_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.687, Active ACC:  0.723
# 10 queries:
# Random ACC:  0.806, Active ACC:  0.826
# 15 queries:
# Random ACC:  0.859, Active ACC:  0.878
# 20 queries:
# Random ACC:  0.873, Active ACC:  0.908
#
# Times SSC overcomes Random Sampling:  32
# Highest performance of SSC with 29 queries
# Random ACC:  0.895, Active ACC:  0.914
# Algorithm: nEQB  |  Diversity Criterion: clustering_div
# --------------------------------------------------------------
# 5 queries:
# Random ACC:  0.652, Active ACC:  0.735
# 10 queries:
# Random ACC:  0.817, Active ACC:  0.781
# 15 queries:
# Random ACC:  0.856, Active ACC:  0.829
# 20 queries:
# Random ACC:  0.875, Active ACC:  0.870
#
# Times nEQB overcomes Random Sampling:  24
# Highest performance of nEQB with 40 queries
# Random ACC:  0.909, Active ACC:  0.923

# %% [markdown]
# #### Resultados del primer ejercicio:
# En este ejercicio, como dicta el enunciado, se han escogido 10 puntos por cada query, hasta llegar a un total de 40 queries.
#
# <b>Marging Sampling</b>:<br>
# En comparación a un muestreo aleatorio, la estrategia de margin sampling no obtiene un mejor acierto de clasificación (Accuracy score) por sí sola, ni empleando el método de diversidad Mao. Se obtienen ciertas mejoras en el rendimiento, si bien no son significativas, con los criterios de diversidad Mao Lambda, y Clustering a partir de 10 queries.<br>
# <br>
# <b>MCLU</b>:<br>
# En comparación con un muestreo aleatorio, la estrategia de MCLU  obtiene un mejor rendimiento, en solitario y con un criterio de diversidad. Cabe comentar que con el criterio de diversidad de clustering, a partir de 40 queries, el acierto de clasificación del muestreo aleatorio es mejor. <br>
# <br>
# <b>SSC</b>:<br>
# Los resultados de rendimiento obtenidos con la estrategia SSC son más variados. En un principio, en comparación con el muestro aleatorio y sin aplicar un criterio de diversidad, el SSC obtiene un mejor rendimiento.
# Con el criterio Mao, el rendimiento es mejor a partir de 40 queries, y con clustering a partir de 30 queries. Con el criterio Mao Lambda, el rendimiento en comparación a un muestreo aleatorio, solo es mejor hasta 10 queries.<br>
# <br>
# <b>nEQB</b>:<br>
# En la misma línea que Margin Sampling, si comparamos el rendimiento con un muestreo aleatorio, no se obtienen mejores resultados, si bien empleando el criterio de diversidad Clustering, y hasta 15 queries.

# %% [markdown]
# #### Ejercicio 2
# En este ejercicio repetiremos el experimento llevado a cabo en el ejercicio 1, 50 veces, con el objetivo de obtener resultados estadísticamente significativos.<br>
#
# Tal y como en el ejercicio anterior, tomaremos 10 muestras por cada query, hasta un número total de 40 queries. Los resultados finales mostrarán el acierto en clasificación (accuracy) promedio interexperimento para cada query.
#
# Con el fin de ilustrar los resultados mostraremos una gráfica parecida a la del ejercicio 1, incluyendo dos desviaciones típicas del acierto en clasificación promedio interexperimento.

# %%
# AL Variables
num_queries = 40
query_points = 10
num_of_experiments = 50

classes = np.unique(labels)
n_classes = len(classes)

# Packing AL Algorithms % Diversity Criterions
algorithms = [MarginSampling, MCLU, SSC,  nEQB]

div_methods = ["none", "mao_div", "mao_lambda_div", "clustering_div"]

# Saving average accuracies & 2*sd
AL_information = pd.DataFrame()
alg_names = []
alg_div_names = []
random_acc = []
al_acc = []
std2 = []
experiment_row_list = []
queries_row_list = []

start_time = time.time()
for exp in range(num_of_experiments):
    # Set up random and active objects inside the experiment loop
    random = ao()
    xtest, ytest = random.setup(labeled_data, labels, unlabeled_data, labels_u, test_data, test_labels)
    white_class = random.copy()
    experiment = exp+1
    for d in range(len(div_methods)):
        for k in range(len(algorithms)):
            # Update class instances for each AL algorithm iteration
            active = white_class.copy()
            random = white_class.copy()
            # Save Accuracy for each method
            accr_list = []
            acca_list = []
            for i in np.arange(0, num_queries):
                # Random Method
                Random_Sampling(random.xlab, random.ylab, random.xunlab)
                accr = random.score(xtest, ytest)
                accr_list.append(accr)
                # AL
                algorithm = algorithms[k]
                algorithm(active.xlab, active.ylab, active.xunlab, div_method = div_methods[d])
                acca = active.score(xtest, ytest)
                acca_list.append(acca)

            # Information of every algorithm & experiment must be saved up
            experiment_row_list.extend(np.repeat(experiment, len(acca_list)))
            queries_row = np.arange(1,num_queries+1)
            queries_row_list.extend(queries_row)
            alg_names.extend(np.repeat(algorithms[k].__name__, len(acca_list)))
            alg_div_names.extend(np.repeat(div_methods[d], len(acca_list)))
            random_acc.extend(accr_list)
            al_acc.extend(acca_list)
    # if the loop is in its last iteration, print results:
    if exp == num_of_experiments-1:
        AL_information["Experiment"] = experiment_row_list
        AL_information["nQueries"] = queries_row_list
        AL_information["Algorithm"] = alg_names
        AL_information["Diversity_Method"] = alg_div_names
        AL_information["AL_Accuracy"] = al_acc
        AL_information["Random_Accuracy"] = random_acc
        # Printing Final Results
        for d in range(len(div_methods)):
            for k in range(len(algorithms)):
                accuracies = AL_information[(AL_information.Algorithm == algorithms[k].__name__) & (AL_information.Diversity_Method == div_methods[d])]
                accuracies = accuracies.iloc[:,[1,4,5]]
                accuracies_avg = accuracies.groupby(["nQueries"]).mean()
                accuracies_avg.columns = ["AL_Acc_Avg", "Random_Acc_Avg"]
                accuracies_std = accuracies.groupby(["nQueries"]).std()
                accuracies_std.columns = ["AL_Acc_Std", "Random_Acc_Std"]
                accuracies = pd.concat([accuracies_avg, accuracies_std], axis=1)
                # Printing Information
                print("Algorithm:", algorithms[k].__name__," | ","Diversity Criterion:", div_methods[d], " | ", "Experiment repeated", num_of_experiments, "times")
                print("---------------------------------------------------------------------------------------")
                for quer in [9, 19, 29, 39]:
                    print(quer+1, "queries:")
                    print("Average Random ACC: %6.3f, Average Active ACC: %6.3f" % (accuracies.iloc[quer,1], accuracies.iloc[quer,0]))
                # Saving positions where non-random algorithm overcomes the random one
                aux = accuracies[accuracies["AL_Acc_Avg"] > accuracies["Random_Acc_Avg"]]
                print("\nTimes", algorithms[k].__name__, "overcomes Random Sampling: ", aux.shape[0])
                # Printing in which n of queries AL algorithm performs better
                if aux.shape[0] == 0:
                    aux1 = accuracies.sort_values(["AL_Acc_Avg"], ascending=False)
                    print("Highest average performance of", algorithms[k].__name__, "with", aux1.index[0], "queries:")
                    aux1 = aux1.reset_index(drop=True)
                    print("Average Random ACC: %6.3f, Average Active ACC: %6.3f" % (aux1.iloc[0,1], aux1.iloc[0,0]))
                else:
                    aux1 = aux.sort_values(["AL_Acc_Avg"], ascending=False)
                    print("Highest average performance of", algorithms[k].__name__, "with", aux1.index[0], "queries:")
                    aux1 = aux1.reset_index(drop=True)
                    print("Average Random ACC: %6.3f, Average Active ACC: %6.3f" % (aux1.iloc[0,1], aux1.iloc[0,0]))
                # Plotting Accuracy Graphs
                x_axis = np.arange(0 , 40)
                plt.figure(figsize=(9, 5))
                plt.suptitle("Average Accuracy Scores for " + str(num_of_experiments) + " iterations" + ", Random Sampling VS " + algorithms[k].__name__, fontsize=16)
                plt.title("Diversity Method: " + div_methods[d], fontsize=12)
                plt.ylabel("Accuracy")
                ax = sns.lineplot(data=accuracies.iloc[:,[0,1]], palette="viridis")
                ax.fill_between(x = x_axis, y1 = np.array(accuracies.AL_Acc_Avg.values + 2*accuracies.AL_Acc_Std.values), y2 = np.array(accuracies.AL_Acc_Avg.values + -(2*accuracies.AL_Acc_Std.values)), alpha = 0.4)
                ax.fill_between(x = x_axis, y1 = np.array(accuracies.Random_Acc_Avg.values + 2*accuracies.Random_Acc_Std.values), y2 = np.array(accuracies.Random_Acc_Avg.values + -(2*accuracies.Random_Acc_Std.values)), alpha = 0.4, color = "#66e882")
                ax.legend(loc="lower right", title = "Algorithms", labels = [algorithms[k].__name__, "Random Sampling"])
                plt.show()
                print("\n")
            if  d == (len(div_methods)-1):
                elapsed_time = time.time() - start_time
                print("Time:")
                print(time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# Algorithm: MarginSampling  |  Diversity Criterion: none  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.803, Average Active ACC:  0.735
# 20 queries:
# Average Random ACC:  0.880, Average Active ACC:  0.804
# 30 queries:
# Average Random ACC:  0.906, Average Active ACC:  0.829
# 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.861
#
# Times MarginSampling overcomes Random Sampling:  0
# Highest average performance of MarginSampling with 39 queries:
# Average Random ACC:  0.919, Average Active ACC:  0.864
# Algorithm: MCLU  |  Diversity Criterion: none  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.797, Average Active ACC:  0.854
# 20 queries:
# Average Random ACC:  0.878, Average Active ACC:  0.909
# 30 queries:
# Average Random ACC:  0.906, Average Active ACC:  0.926
# 40 queries:
# Average Random ACC:  0.921, Average Active ACC:  0.937
#
# Times MCLU overcomes Random Sampling:  36
# Highest average performance of MCLU with 40 queries:
# Average Random ACC:  0.921, Average Active ACC:  0.937
# Algorithm: SSC  |  Diversity Criterion: none  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.803, Average Active ACC:  0.803
# 20 queries:
# Average Random ACC:  0.880, Average Active ACC:  0.881
# 30 queries:
# Average Random ACC:  0.907, Average Active ACC:  0.907
# 40 queries:
# Average Random ACC:  0.921, Average Active ACC:  0.922
#
# Times SSC overcomes Random Sampling:  28
# Highest average performance of SSC with 40 queries:
# Average Random ACC:  0.921, Average Active ACC:  0.922
# Algorithm: nEQB  |  Diversity Criterion: none  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.801, Average Active ACC:  0.807
# 20 queries:
# Average Random ACC:  0.878, Average Active ACC:  0.878
# 30 queries:
# Average Random ACC:  0.906, Average Active ACC:  0.907
# 40 queries:
# Average Random ACC:  0.922, Average Active ACC:  0.922
#
# Times nEQB overcomes Random Sampling:  18
# Highest average performance of nEQB with 40 queries:
# Average Random ACC:  0.922, Average Active ACC:  0.922
# Algorithm: MarginSampling  |  Diversity Criterion: mao_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.803, Average Active ACC:  0.715
# 20 queries:
# Average Random ACC:  0.880, Average Active ACC:  0.815
# 30 queries:
# Average Random ACC:  0.907, Average Active ACC:  0.890
# 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.904
#
# Times MarginSampling overcomes Random Sampling:  0
# Highest average performance of MarginSampling with 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.904
# Algorithm: MCLU  |  Diversity Criterion: mao_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.808, Average Active ACC:  0.795
# 20 queries:
# Average Random ACC:  0.879, Average Active ACC:  0.933
# 30 queries:
# Average Random ACC:  0.909, Average Active ACC:  0.944
# 40 queries:
# Average Random ACC:  0.923, Average Active ACC:  0.937
#
# Times MCLU overcomes Random Sampling:  35
# Highest average performance of MCLU with 29 queries:
# Average Random ACC:  0.907, Average Active ACC:  0.947
# Algorithm: SSC  |  Diversity Criterion: mao_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.801, Average Active ACC:  0.740
# 20 queries:
# Average Random ACC:  0.883, Average Active ACC:  0.847
# 30 queries:
# Average Random ACC:  0.908, Average Active ACC:  0.891
# 40 queries:
# Average Random ACC:  0.923, Average Active ACC:  0.914
#
# Times SSC overcomes Random Sampling:  0
# Highest average performance of SSC with 40 queries:
# Average Random ACC:  0.923, Average Active ACC:  0.914
# Algorithm: nEQB  |  Diversity Criterion: mao_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.802, Average Active ACC:  0.732
# 20 queries:
# Average Random ACC:  0.879, Average Active ACC:  0.850
# 30 queries:
# Average Random ACC:  0.906, Average Active ACC:  0.893
# 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.916
#
# Times nEQB overcomes Random Sampling:  0
# Highest average performance of nEQB with 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.916
# Algorithm: MarginSampling  |  Diversity Criterion: mao_lambda_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.804, Average Active ACC:  0.804
# 20 queries:
# Average Random ACC:  0.879, Average Active ACC:  0.829
# 30 queries:
# Average Random ACC:  0.908, Average Active ACC:  0.864
# 40 queries:
# Average Random ACC:  0.922, Average Active ACC:  0.897
#
# Times MarginSampling overcomes Random Sampling:  3
# Highest average performance of MarginSampling with 11 queries:
# Average Random ACC:  0.814, Average Active ACC:  0.815
# Algorithm: MCLU  |  Diversity Criterion: mao_lambda_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.805, Average Active ACC:  0.842
# 20 queries:
# Average Random ACC:  0.879, Average Active ACC:  0.911
# 30 queries:
# Average Random ACC:  0.907, Average Active ACC:  0.922
# 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.937
#
# Times MCLU overcomes Random Sampling:  38
# Highest average performance of MCLU with 39 queries:
# Average Random ACC:  0.919, Average Active ACC:  0.939
# Algorithm: SSC  |  Diversity Criterion: mao_lambda_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.802, Average Active ACC:  0.746
# 20 queries:
# Average Random ACC:  0.881, Average Active ACC:  0.820
# 30 queries:
# Average Random ACC:  0.908, Average Active ACC:  0.857
# 40 queries:
# Average Random ACC:  0.921, Average Active ACC:  0.882
#
# Times SSC overcomes Random Sampling:  2
# Highest average performance of SSC with 3 queries:
# Average Random ACC:  0.551, Average Active ACC:  0.571
# Algorithm: nEQB  |  Diversity Criterion: mao_lambda_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.798, Average Active ACC:  0.703
# 20 queries:
# Average Random ACC:  0.879, Average Active ACC:  0.835
# 30 queries:
# Average Random ACC:  0.907, Average Active ACC:  0.895
# 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.923
#
# Times nEQB overcomes Random Sampling:  4
# Highest average performance of nEQB with 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.923
# Algorithm: MarginSampling  |  Diversity Criterion: clustering_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.803, Average Active ACC:  0.768
# 20 queries:
# Average Random ACC:  0.881, Average Active ACC:  0.848
# 30 queries:
# Average Random ACC:  0.907, Average Active ACC:  0.868
# 40 queries:
# Average Random ACC:  0.921, Average Active ACC:  0.871
#
# Times MarginSampling overcomes Random Sampling:  2
# Highest average performance of MarginSampling with 3 queries:
# Average Random ACC:  0.540, Average Active ACC:  0.555
# Algorithm: MCLU  |  Diversity Criterion: clustering_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.798, Average Active ACC:  0.850
# 20 queries:
# Average Random ACC:  0.878, Average Active ACC:  0.895
# 30 queries:
# Average Random ACC:  0.908, Average Active ACC:  0.929
# 40 queries:
# Average Random ACC:  0.922, Average Active ACC:  0.933
#
# Times MCLU overcomes Random Sampling:  39
# Highest average performance of MCLU with 37 queries:
# Average Random ACC:  0.919, Average Active ACC:  0.936
# Algorithm: SSC  |  Diversity Criterion: clustering_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.796, Average Active ACC:  0.798
# 20 queries:
# Average Random ACC:  0.880, Average Active ACC:  0.879
# 30 queries:
# Average Random ACC:  0.908, Average Active ACC:  0.905
# 40 queries:
# Average Random ACC:  0.923, Average Active ACC:  0.919
#
# Times SSC overcomes Random Sampling:  18
# Highest average performance of SSC with 25 queries:
# Average Random ACC:  0.896, Average Active ACC:  0.896
# Algorithm: nEQB  |  Diversity Criterion: clustering_div  |  Experiment repeated 50 times
# ---------------------------------------------------------------------------------------
# 10 queries:
# Average Random ACC:  0.799, Average Active ACC:  0.805
# 20 queries:
# Average Random ACC:  0.876, Average Active ACC:  0.881
# 30 queries:
# Average Random ACC:  0.909, Average Active ACC:  0.910
# 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.922
#
# Times nEQB overcomes Random Sampling:  38
# Highest average performance of nEQB with 40 queries:
# Average Random ACC:  0.920, Average Active ACC:  0.922
# Time:
# 02:17:29

# %% [markdown]
# #### Resultados del segundo ejercicio:
#
# <b>Marging Sampling</b>:<br>
# En comparación a un muestreo aleatorio, la estrategia de margin sampling no obtiene un mejor acierto de clasificación (Accuracy score) promedio interexperimento, por sí sola, ni empleando el método de diversidad Mao, ni clustering. Se obtienen ciertas mejoras en el rendimiento, si bien no son significativas, con el criterio de diversidad Mao Lambda a partir de 20 queries.<br>
# <br>
# <b>MCLU</b>:<br>
# En comparación con un muestreo aleatorio, la estrategia de MCLU obtiene un mejor acierto de clasificación promedio interexperimento, en solitario y conjunto un criterio de diversidad. Si bien cabe mencionar que con el criterio de diversidad de Mao, esta mejora en el acierto se observa a partir de 20 queries.<br>
# <br>
# <b>SSC</b>:<br>
# Los resultados de rendimiento obtenidos con la estrategia SSC son más variados. En un principio, en comparación con el muestro aleatorio y sin aplicar un criterio de diversidad, el SSC obtiene un mejor rendimiento.
# Con el criterio Mao, el rendimiento no es mejor en comparación al muestreo aleatorio. Con el criterio de clustering, el acierto de clasificación promedio interexperimento es mejor hasta 20 queries.<br>
# <br>
# <b>nEQB</b>:<br>
# Si comparamos el acierto de clasificación promedio interexperimento del nEQB con un muestreo aleatorio, los resultados son un poco más diversos. nEQB sin criterio de diversidad y con el criterio de clustering presentan mejor rendimiento, al contrario, en combinación con el criterio de Mao el rendimiento no es mejor que empleando un muestreo aleatorio, y si se emplea Mao Lambda, el rendimiento del método de AL mejora a partir de 40 queries.
